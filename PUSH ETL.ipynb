# %%
from google.oauth2 import service_account
import pandas as pd
import pandas_gbq
import seaborn as sns

superstore = (r"C:\Users\sulae\Desktop\PURWADHIKA\JCDS 2804\HANDS ON\MODUL 2\PORTOFOLIO\output\sales_superstore_analysis_cleaned.xlsx")
project_id = 'sales-superstore-analysis'
dataset_id = 'superstore'
table_name = 'sales_superstore_analysis_cleaned'
key_path = r'C:\Users\sulae\Desktop\PURWADHIKA\JCDS 2804\HANDS ON\MODUL 2\DAY 24 - ETL\HANDSON GOOGLE BIGQUERY\heroic-charter-453502-g8-0f728c06608e.json'
scopes = ['https://www.googleapis.com/auth/bigquery']
credentials = service_account.Credentials.from_service_account_file(key_path, scopes=scopes)

pandas_gbq.to_gbq(
    titanic, 
    f'{dataset_id}.{table_name}', 
    project_id=project_id, 
    if_exists='replace', 
    credentials=credentials
    )
